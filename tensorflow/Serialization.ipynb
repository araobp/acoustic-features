# %% [markdown]
# # Dataset serialization test
#
# Date: March 23, 2019

# %%
import matplotlib.pyplot as plt

# %run ../oscilloscope/script/dataset.py
# %matplotlib inline

# %%
DATASET_FOLDER = '../dataset/data_environment'
ds = DataSet(DATASET_FOLDER)
ds.serialize()

# %%
data = ds._load()
plt.imshow(data['train'][43][0].reshape(64,40))

# %%
len(data['mall'])
# Out:
# 200

# %%
data['mall'][0]
# Out:
# [array([-12., -15., -15., ..., -11., -10., -14.]),
#  array([  0., -21.,  16., ...,  -2.,  -2.,   0.])]

# %%
data = ds.generate()
plt.imshow(data['mfsc'][0][3].reshape(64, 40))

# %%
train_data, train_labels, test_data, test_labels = ds.generate()['mfsc']

SAVED_MODEL = '../dataset/data_environment/cnn_for_aed_environment20190320110504.h5'
model = models.load_model(SAVED_MODEL)
shape = ds.shape
class_labels = ds.class_labels

# %%
image_number = 99

plt.imshow(np.rot90(test_data[image_number,:,:,0]), cmap='gray')
plt.savefig('input.png')
class_labels[np.argmax(test_labels[image_number])]
# Out:
# 'silence'

# %%
layer_outputs = [layer.output for layer in model.layers]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(test_data)

# %%
plot_layer(activations, image_number, 0, 4)

# %%
plot_layer(activations, image_number, 1, 4)

# %%
plot_layer(activations, image_number, 3, 8)
plt.savefig('layer3.png')

# %%
plot_layer(activations, image_number, 4, 8)
plt.savefig('layer4.png')

# %%
plot_layer(activations, image_number, 6, 16)
plt.savefig('layer4.png')

# %%
plot_layer(activations, image_number, 7, 16)
plt.savefig('layer5.png')
